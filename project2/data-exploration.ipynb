# %% [markdown]
# # Libraries import

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib notebook

# %% [markdown]
# # Data import

# %%
filename_measures = 'data/IMPROVE_2015_measures_cs433.csv'
filename_spectra = 'data/IMPROVE_2015_raw_spectra_cs433.csv'
# filename_tts = 'data/IMPROVE_2015_train_test_split_cs433.csv'
# filename_sec_deriv = 'data/IMPROVE_2015_2nd-derivative_spectra_cs433.csv'

df_measures = pd.read_csv(filename_measures)
df_spectra = pd.read_csv(filename_spectra).T
# df_train_test_split = pd.read_csv(filename_tts)
# df_second_derivative = pd.read_csv(filename_sec_deriv, index_col=0)

# %%
df_spectraectra.head()
# Out:
#                                   0            1            2            3     \
# wavenumber                 3998.423206  3997.137539  3995.851872  3994.566206
# ACAD1_01_06_2015_NM_0_csv     0.357780     0.357600     0.357430     0.357250
# ACAD1_01_09_2015_NM_0_csv     0.588580     0.588320     0.588060     0.587810
# ACAD1_01_12_2015_NM_0_csv     0.550910     0.550550     0.550190     0.549840
# ACAD1_01_15_2015_NM_0_csv     0.497390     0.497150     0.496900     0.496650
#
#                                   4            5            6            7     \
# wavenumber                 3993.280539  3991.994872  3990.709206  3989.423539
# ACAD1_01_06_2015_NM_0_csv     0.357080     0.356890     0.356710     0.356520
# ACAD1_01_09_2015_NM_0_csv     0.587560     0.587310     0.587070     0.586820
# ACAD1_01_12_2015_NM_0_csv     0.549480     0.549120     0.548750     0.548380
# ACAD1_01_15_2015_NM_0_csv     0.496400     0.496150     0.495900     0.495640
#
# ...

# %% [markdown]
# # First peek

# %% [markdown]
# ## measures

# %%
df_measures.groupby('flag').count()['site'].plot.bar(logy=True)

# %%
df_measures.groupby('SiteCode').count()['site']
# Out:
# SiteCode
# ACAD1    119
# AGTI1     96
# BADL1    117
# BALA1    118
# BALD1    111
# BAND1    110
# BIBE1    114
# BIRM1    123
# BLIS1    117
# BLMO1    113
# BOAP1    104
# BOLA1    109
# BOND1    118
# BOWA1    118
# BRCA1    119
# BRID1    120
# BRIG1    112
# BRIS1    113
# BRMA1    118
# BYIS1     99
# CABA1    106
# CABI1    112
# CACO1     70
# CACR1    114
# CANY1    106
# CAPI1    114
# CEBL1    119
# CHAS1    120
# CHIR1    121
# CLPE1     57
#         ...
# SNPA1    110
# STAR1    119
# STIL1    113
# SULA1     39
# SWAN1    112
# SYCA1     91
# SYCA2      1
# TALL1    116
# THBA1    107
# THRO1    111
# THSI1    119
# TONT1    115
# TRCR1    115
# TRIN1     70
# ULBE1    115
# UPBU1    115
# VIIS1    109
# VILA1    122
# VOYA1    116
# WASH1     41
# WEMI1    116
# WHIT1    112
# WHPA1     96
# WHPE1     97
# WHRI1    117
# WICA1    119
# WIMO1    116
# YELL1    118
# YOSEX    113
# ZICA1    108
# Name: site, Length: 164, dtype: int64

# %%
df_measures['DUSTf:Value'].sort_values().reset_index()['DUSTf:Value'].plot()

# %%
df_measures[df_measures['DUSTf:Value'] > 30]
# Out:
#        Unnamed: 0                          site SiteCode      Date flag  \
# 61             61     TONT1_06_20_2015_NM_0_csv    TONT1  20150620   NM
# 78             78     BRIS1_07_02_2015_NM_0_csv    BRIS1  20150702   NM
# 154           154     VIIS1_06_08_2015_NM_0_csv    VIIS1  20150608   NM
# 254           254  UPBU1_07_11_2015_NM_QC_0_csv    UPBU1  20150711   NM
# 255           255     UPBU1_07_11_2015_NM_0_csv    UPBU1  20150711   NM
# 308           308     SWAN1_05_12_2015_NM_0_csv    SWAN1  20150512   NM
# 344           344     TONT1_06_17_2015_NM_0_csv    TONT1  20150617   NM
# 359           359     WHIT1_06_23_2015_NM_0_csv    WHIT1  20150623   NM
# 411           411     PHOE5_04_12_2015_NM_1_csv    PHOE5  20150412   NM
# 421           421     CABI1_06_29_2015_NM_0_csv    CABI1  20150629   NM
# 422           422  CABI1_06_29_2015_NM_QC_0_csv    CABI1  20150629   NM
# 434           434     BLMO1_10_06_2015_NM_0_csv    BLMO1  20151006   NM
# ...

# %% [markdown]
# ## spectra

# %%
df_spectra
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-cc9ba09555b3> in <module>
# ----> 1 df_spectra
#
# NameError: name 'df_spectra' is not defined

# %%
df_spectra.describe()

# %% [markdown]
# ## train test split

# %%
df_train_test_split
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-b2890e66131a> in <module>
# ----> 1 df_train_test_split
#
# NameError: name 'df_train_test_split' is not defined

# %%
df_train_test_split.describe()

# %% [markdown]
# ## Second derivative

# %%
df_second_derivative

# %%
df_second_derivative.describe()
